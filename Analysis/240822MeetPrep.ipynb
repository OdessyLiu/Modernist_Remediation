# %%
import pandas as pd

# %%
data135_path = "../Data/Web-Scraped_Data/AllReviews_135_Unique.csv"
data135 = pd.read_csv(data135_path)
data135.head()
# Out:
#                                           Title  Review_Author   Account_Type  \
# 0  Bowie: Stardust, Rayguns & Moonage Daydreams     Bivi Zyggy     38 reviews
# 1  Bowie: Stardust, Rayguns & Moonage Daydreams    Christopher    263 reviews
# 2  Bowie: Stardust, Rayguns & Moonage Daydreams           Tina  1,058 reviews
# 3  Bowie: Stardust, Rayguns & Moonage Daydreams          Sarri    710 reviews
# 4  Bowie: Stardust, Rayguns & Moonage Daydreams  George Taylor    297 reviews
#
#   Author_Social_Stats  Social_Stats        Review_Date  \
# 0                 NaN   9 followers       June 2, 2022
# 1                 NaN    1 follower      March 7, 2020
# 2                 NaN  30 followers  November 24, 2020
# 3                 NaN   8 followers  February 16, 2021
# 4                 NaN   7 followers       May 19, 2023
#
#                                   Review_Star_Rating  \
# 0  <span aria-label="Rating 5 out of 5" role="img...
# 1  <span aria-label="Rating 5 out of 5" role="img...
# ...
